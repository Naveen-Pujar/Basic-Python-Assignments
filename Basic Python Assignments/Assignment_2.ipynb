# %% [markdown]
# # Assignment - 2

# %% [markdown]
# ### 1.What are the two values of the Boolean data type? How do you write them?
#
# ### Solution:
#
# ### The two values of a boolean type are 'True' or 'False'.
#
# ## bool() ### method is used to return/convert boolean values

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 2. What are the three different types of Boolean operators?
#
# ### Solution:
#
# ### 'and' , 'or' , and 'not'

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).
#
# ### Solution:
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 4. What are the values of the following expressions?
# ## (5 > 4) and (3 == 5)
# ## not (5 > 4)
# ## (5 > 4) or (3 == 5)
# ## not ((5 > 4) or (3 == 5))
# ## (True and True) and (True == False)
# ## (not False) or (not True)
#
# ### Solution:
#
#
# ### (5 > 4) and (3 == 5) : False
# ### not (5 > 4) : False
# ### (5 > 4) or (3 == 5): True
# ### not ((5 > 4) or (3 == 5)) : False
# ### (True and True) and (True == False): False
# ### (not False) or (not True): True

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 5. What are the six comparison operators?
#
# ### Solution:
#
# ### < (If the left value is less than the right value, then the condition becomes true.),
#
# ### > (If the left value is more than the right value, then the condition becomes true.),
# ### == (If the left value is same as the right value, then the condition becomes true.),
# ### >= (If the right value is more than or equal to the right value, then the condition becomes true.),
# ### <= (If the left value is less than or equal to the right value, then the condition becomes true.),
# ### != (If the left value is not equal to the right value, then the condition becomes true.),,

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 6. How do you tell the difference between the equal to and assignment operators?Describe a condition and when you would use one.
#
# ### Solution
#
# ### 'equal to' is a comparison operator denoated by '==' sign and it returns a boolean result (True/False) after evaluation of an expression. For ex 1 == 1 results in True. One would use equal to operator to check if values on either side of the operator are equal or not and the output will be displayed as boolean objects where True means the values on the either side are equal and False means that the values are not equal.
#
# ### single equal sign (=) is an assignment opertor which is used to assign some value/data to a variable. For ex v = 4.56. Here value 4.56 is able to be stored within variable 'v' with the help of sign equal to sign.

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 7. Identify the three blocks in this code:
# ## spam = 0
# ## if spam == 10:
# ## print('eggs')
# ## if spam > 5:
# ## print('bacon')
# ## else:
# ## print('ham')
# ## print('spam')
# ## print('spam')
#
#
#
# ### Solution:
#
# ### spam = 0
#
# #### First block
# ### if spam == 10:
# ### print('eggs')
#
# #### Second block
# ### if spam > 5:
# ### print('bacon')
#
# #### Third block
# ### else:
# ### print('ham')
# ### print('spam')
# ### print('spam')

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.
#
# spam = ''
#
# if spam ==1:
#     print('Hello')
#
# elif spam == 2:
#     print('Howdy')
#
# else:
#     print('greetings')

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------
